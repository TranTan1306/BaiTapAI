# %% [markdown]
# <a href="https://colab.research.google.com/github/TranTan1306/BaiTapAI/blob/main/W7_Homeworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **50 Startups**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = '/content/50_Startups.csv'
data = pd.read_csv(url)
data.head()
data.hist()
plt.show()

# %%
correlations = data.corr()
correlations
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(correlations, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
# Out:
# LinearRegression()

# %%
# intercept
model.intercept_
# Out:
# 49032.89914125215

# %%
# coefficient
print(model.coef_)
# Out:
# [0.85429137]

# %%
# accuracy
model.score(X = pd.DataFrame(data['R&D Spend']), y = data['Profit'])
# Out:
# 0.9465353160804393

# %%
# prediction
y_pred = model.predict(X = pd.DataFrame(data['R&D Spend']))
print(y_pred)
# Out:
# [190289.29389289 187938.71118575 180116.65707807 172369.00320589
#  170433.97345032 161694.19683741 164033.72501421 160345.46724972
#  152011.33380847 154396.82286103 136096.36397105 135036.08586475
#  129219.89081021 127621.20411029 151499.37407569 146869.43093301
#  115678.82583435 129897.69412683 127413.41482014 122860.50313037
#  114175.91374003 116000.34693472 112245.81324567 106725.35677792
#  114850.93206678 104275.40289851 113385.70276482 110633.79960036
#  105460.14271464 105079.09459155 101994.24845109 101261.18102569
#  103202.54108032  96440.90176556  88694.29012885  88342.27936946
#   73520.10196791  86681.47714396  66314.86331588  81973.10151051
#   73597.47513738  72861.58000754  69229.14164122  62279.31048036
#   67979.15105018  49887.38699921  50156.68526807  49032.89914125
#   49495.96777887  49032.89914125]

# %%
# sketch the graph
data.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize=(9,9), color = 'black')
plt.plot(data['R&D Spend'], y_pred, color='yellow')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 2nd order
model=linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('Intercept:',model.intercept_)
print('Coeffient:',model.coef_)
print('Accuracy:',model.score(X,data['Profit']))
# Out:
# Intercept: 48128.14916956878
# Coeffient: [ 8.90147291e-01 -2.31821806e-07]
# Accuracy: 0.946703652909133

# %%
range=np.arange(0,180000,0.1)
x_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=x_range)
data.plot(kind='scatter',
          x='R&D Spend',
          y='Profit',
          figsize=(9,9),
          color='black')
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame(data.loc[:,['R&D Spend','Administration']])
model.fit(X=data.loc[:,['R&D Spend','Administration']], y =data['Profit'])
print('Intercept:', model.intercept_)
print('coeffient:', model.coef_)
print('Accuracy:',model.score(X,data['Profit']))
# Out:
# Intercept: 54886.62062756297
# coeffient: [ 0.86211798 -0.05299543]
# Accuracy: 0.9478129385009173

# %%
# 3rd order
model=linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y=data['Profit'])
print('Intercept:',model.intercept_)
print('Coeffient:',model.coef_)
print('Accuracy:',model.score(X,data['Profit']))
# Out:
# Intercept: 43108.76756818297
# Coeffient: [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Accuracy: 0.9540709421464032

# %%
range=np.arange(0,180000,100)
x_range=pd.DataFrame([range,range**2,range**3]).T
y_pred=model.predict(X=x_range)
data.plot(kind='scatter',
          x='R&D Spend',
          y='Profit',
          figsize=(9,9),
          color='black')
plt.plot(range,y_pred,color='green')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# **INSURANCE**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
url = '/content/insurance.csv'
data = pd.read_csv(url)
data.hist()
plt.show()

# %%
correlations = data.corr()
correlations
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(correlations,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
x = pd.DataFrame(data['charges'])
model.fit(x, data['age'])
print('Intercept:', model.intercept_)
print('Coeficient:', model.coef_)
print('Accuracy:', model.score(x, data['age']))
# Out:
# Intercept: 34.603416896331794
# Coeficient: [0.00034691]
# Accuracy: 0.08940589967885781

# %%
y_pred = model.predict(x)
data.plot(kind='scatter', x='charges', y='age', figsize = (9,9), color='black')
plt.plot(data['charges'], y_pred, color='violet')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 4th order
model = linear_model.LinearRegression()
x = pd.DataFrame([data['charges'], data['charges']**2, data['charges']**3, data['charges']**4]).T
model.fit(x, data['age'])
print('Intercept:', model.intercept_)
print('Coeficient:',model.coef_)
print('Accuracy',model.score(x,data['age']))
# Out:
# Intercept: 3.303433683236129
# Coeficient: [ 8.86005365e-03 -5.54698255e-07  1.26612497e-11 -9.40375978e-17]
# Accuracy 0.544474278954871

# %%
range = np.arange(0,6500,100)
x_range = pd.DataFrame([range,range**2,range**3,range**4]).T
y_pred = model.predict(x_range)
data.plot(kind='scatter',x='charges',y='age',figsize=(9,9),color='black')
plt.plot(range, y_pred, color='green')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# **ADVERTISING**

# %%
import numpy as np
import pandas as pd
url = '/content/Advertising.csv'
data = pd.read_csv(url)
data.head()
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlations = data.corr()
correlations
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns
sns.heatmap(correlations, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
x = pd.DataFrame(data['TV'])
model.fit(x, data['sales'])
print('Intercept of the model:', model.intercept_)
print('Coeficient of the model:', model.coef_)
print('Accuracy of the model:', model.score(x, data['sales']))
# Out:
# Intercept of the model: 7.032593549127695
# Coeficient of the model: [0.04753664]
# Accuracy of the model: 0.611875050850071

# %%
y_pred = model.predict(x)
data.plot(kind='scatter', x='TV', y='sales', figsize=(9,9), color='black')
plt.plot(data['TV'], y_pred, color='violet')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 2nd order
model = linear_model.LinearRegression()
model.fit(pd.DataFrame([data['TV'], data['TV']**2]).T, data['sales'])
print('Intercept:', model.intercept_)
print('Coeficient:', model.coef_)
print('Accuracy:', model.score(pd.DataFrame([data['TV'], data['TV']**2]).T, data['sales']))
# Out:
# Intercept: 6.1141201283331075
# Coeficient: [ 6.72659270e-02 -6.84693373e-05]
# Accuracy: 0.6190371168872755

# %%
range = np.arange(0,320,0.1)
x_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(x_range)
data.plot(kind='scatter',
          x='TV',
          y='sales',
          figsize=(9,9),
          color='black')
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 3nd order
model = linear_model.LinearRegression()
x = pd.DataFrame([data['TV'], data['TV']**2, data['TV']**3]).T
model.fit(x, data['sales'])
print('Intercept:', model.intercept_)
print('Coeficient:', model.coef_)
print('Accuracy:', model.score(x, data['sales']))

range = np.arange(0,320,0.1)
x_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(x_range)
data.plot(kind='scatter',
          x='TV',
          y='sales',
          figsize=(9,9),
          color='black')
plt.plot(range,y_pred,color='green')
# Out:
# Intercept: 5.420106548191448
# Coeficient: [ 9.64341770e-02 -3.15222433e-04  5.57199796e-07]
# Accuracy: 0.6220016830036417
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 5th order
model = linear_model.LinearRegression()
x = pd.DataFrame([data['TV'], data['TV']**2, data['TV']**3, data['TV']**4, data['TV']**5]).T
model.fit(x, data['sales'])
print('Intercept:', model.intercept_)
print('Coeficient:', model.coef_)
print('Accuracy:', model.score(x, data['sales']))

range = np.arange(0,320,0.1)
x_range = pd.DataFrame([range, range**2, range**3, range**4, range**5]).T
y_pred = model.predict(x_range)
data.plot(kind='scatter',
          x='TV',
          y='sales',
          figsize=(9,9),
          color='black')
plt.plot(range,y_pred,color='green')
# Out:
# Intercept: 3.434534787401425
# Coeficient: [ 2.77902843e-01 -4.26334402e-03  3.38693899e-05 -1.20207585e-07
#   1.55728366e-10]
# Accuracy: 0.6289510709142143
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# **CRABS**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = '/content/crabs.csv'
data = pd.read_csv(url)
data.head()
data.hist()
plt.show()

# %%
correlations = data.corr()
correlations
# Out:
#               index  fontallip  rearwidth    length     width     depth
# index      1.000000   0.862876   0.840040  0.911436  0.928248  0.864459
# fontallip  0.862876   1.000000   0.906988  0.978842  0.964956  0.987627
# rearwidth  0.840040   0.906988   1.000000  0.892743  0.900402  0.889205
# length     0.911436   0.978842   0.892743  1.000000  0.995023  0.983204
# width      0.928248   0.964956   0.900402  0.995023  1.000000  0.967812
# depth      0.864459   0.987627   0.889205  0.983204  0.967812  1.000000

# %%
import seaborn as sns
sns.heatmap(correlations,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(pd.DataFrame(data['depth']), data['width'])
print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_)
print('Accuracy:', model.score(pd.DataFrame(data['depth']), data['width']))
# Out:
# Intercept: 5.202980685420513
# Coefficient: [2.2245479]
# Accuracy: 0.9366593985807309

# %%
y_pred = model.predict(pd.DataFrame(data['depth']))
data.plot(kind='scatter', x='depth', y='width', figsize=(9,9), color='black')
plt.plot(data['depth'],y_pred,color='violet')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 2nd order
model = linear_model.LinearRegression()
X = pd.DataFrame([data['depth'], data['depth']**2]).T
model.fit(X, data['width'])
print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_)
print('Accuracy:', model.score(X, data['width']))
# Out:
# Intercept: 0.8261365540863963
# Coefficient: [ 2.88600538 -0.02351625]
# Accuracy: 0.9384016078898988

# %%
import numpy as np
range = np.arange(5,23,0.1)
x_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(x_range)
data.plot(kind='scatter', x='depth', y='width', figsize=(9,9), color='black')
plt.plot(range, y_pred, color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# **IRIS**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = '/content/iris.csv'
data = pd.read_csv(url)
data.head()
data.hist()
plt.show()

# %%
correlations = data.corr()
correlations
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
import seaborn as sns
sns.heatmap(correlations, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
x = pd.DataFrame(data['petal.width'])
model.fit(x, data['petal.length'])
print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_)
print('Accuracy:', model.score(x, data['petal.length']))
# Out:
# Intercept: 1.0835580328505112
# Coefficient: [2.2299405]
# Accuracy: 0.9271098389904927

# %%
y_pred = model.predict(x)
data.plot(kind='scatter', x='petal.width', y='petal.length', figsize=(9,9), color='black')
plt.plot(data['petal.width'], y_pred, color='violet')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 3nd order
x = pd.DataFrame([data['petal.width'], data['petal.width']**2, data['petal.width']**3]).T
model.fit(x, data['petal.length'])
print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_)
print('Accuracy:', model.score(x, data['petal.length']))

import numpy as np
range = np.arange(0,2.7,0.1)
x_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(x_range)
data.plot(kind='scatter', x='petal.width', y='petal.length', figsize=(9,9), color='black')
plt.plot(range, y_pred, color='green')
# Out:
# Intercept: 1.103398121032987
# Coefficient: [ 1.15270024  1.70995693 -0.57875223]
# Accuracy: 0.9522198169742797
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# **SALARY DATA**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = '/content/Salary_Data.csv'
data = pd.read_csv(url)
data.hist()
plt.show()

# %%
correlations = data.corr()
correlations
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
import seaborn as sns
sns.heatmap(correlations,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame(data['Salary'])
model.fit(X,data['YearsExperience'])
print('Intercept:', model.intercept_)
print('Coeficient:', model.coef_)
print('Accuracy:', model.score(X,data['YearsExperience']))
# Out:
# Intercept: -2.3831605648243537
# Coeficient: [0.00010127]
# Accuracy: 0.9569566641435086

# %%
y_pred = model.predict(X)
data.plot(kind='scatter', x='Salary', y='YearsExperience', figsize=(9,9), color='black')
plt.plot(data['Salary'], y_pred, color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
