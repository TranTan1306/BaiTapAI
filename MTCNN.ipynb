# %% [markdown]
# <a href="https://colab.research.google.com/github/TranTan1306/BaiTapAI/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/people1.jpg'
img = plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
# Out:
# ...
# 7/7 [==============================] - 0s 43ms/step

# %%
for face in faces:
  print(face)
# Out:
# {'box': [1368, 906, 68, 88], 'confidence': 0.9999999403953552, 'keypoints': {'left_eye': (1390, 942), 'right_eye': (1422, 941), 'nose': (1408, 961), 'mouth_left': (1391, 970), 'mouth_right': (1422, 970)}}
# {'box': [665, 905, 82, 102], 'confidence': 0.9999995827674866, 'keypoints': {'left_eye': (691, 944), 'right_eye': (729, 949), 'nose': (708, 966), 'mouth_left': (687, 980), 'mouth_right': (722, 983)}}
# {'box': [1967, 928, 84, 99], 'confidence': 0.9999937415122986, 'keypoints': {'left_eye': (1987, 964), 'right_eye': (2029, 964), 'nose': (2008, 984), 'mouth_left': (1988, 1002), 'mouth_right': (2025, 1003)}}
# {'box': [1686, 815, 40, 48], 'confidence': 0.999991238117218, 'keypoints': {'left_eye': (1701, 833), 'right_eye': (1719, 833), 'nose': (1712, 842), 'mouth_left': (1702, 852), 'mouth_right': (1718, 852)}}
# ...

# %%
filename = '/content/people1.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color='red')
  ax.add_patch(rect)
  plt.savefig('/content/drive/MyDrive/MTCNN_fig2.jpg')
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius=2, color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 7/7 [==============================] - 0s 42ms/step

# %%
filename = '/content/drive/MyDrive/covid19_han_quoc_khau_trang.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color='red')
  ax.add_patch(rect)
  plt.savefig('/content/drive/MyDrive/covid_khautrang.jpg')
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius=2, color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 22ms/step

# %%
filename = '/content/drive/MyDrive/khautrang.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color='red')
  ax.add_patch(rect)
  #plt.savefig('/content/drive/MyDrive/covid_khautrang.jpg')
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius=2, color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 299ms/step

# %%
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1 + width, y1 + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2, x1:x2])
    plt.savefig('/content/drive/MyDrive/people2.jpg')
  plt.show()
filename = '/content/drive/MyDrive/people.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 2/2 [==============================] - 0s 31ms/step

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/chimcanhcut.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02056570', 'king_penguin', 0.9257065), ('n02058221', 'albatross', 0.042965658), ('n01855032', 'red-breasted_merganser', 0.013465366)]

# %%
img_path = '/content/drive/MyDrive/komodo.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 520ms/step
# Predicted: [('n01695060', 'Komodo_dragon', 0.9996681), ('n01692333', 'Gila_monster', 0.00010564431), ('n01677366', 'common_iguana', 9.3263945e-05)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet')

img_path = '/content/drive/MyDrive/komodo.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# ...
# 1/1 [==============================] - 1s 873ms/step
# Predicted: [('n01695060', 'Komodo_dragon', 0.9908408), ('n01677366', 'common_iguana', 0.0052327346), ('n01688243', 'frilled_lizard', 0.0015960962)]

# %%
img_path = '/content/drive/MyDrive/Drinking_Bee.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 642ms/step
# Predicted: [('n01775062', 'wolf_spider', 0.46838292), ('n01774750', 'tarantula', 0.18725859), ('n02206856', 'bee', 0.12995726)]

# %%
img_path = '/content/drive/MyDrive/spider.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 660ms/step
# Predicted: [('n01775062', 'wolf_spider', 0.67784595), ('n01773549', 'barn_spider', 0.24333644), ('n01773797', 'garden_spider', 0.039588943)]

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = '/content/drive/MyDrive/4Airbus-A320.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)
print('Predicted:', decode_predictions(block4_pool_features, top=10))
# Out:
# 1/1 [==============================] - 1s 835ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-fd7bd147ceda> in <cell line: 17>()
#      15
#      16 block4_pool_features = model.predict(x)
# ---> 17 print('Predicted:', decode_predictions(block4_pool_features, top=10))
#
# /usr/local/lib/python3.9/dist-packages/keras/applications/resnet.py in decode_predictions(preds, top)
#     619 )
#     620 def decode_predictions(preds, top=5):
# --> 621     return imagenet_utils.decode_predictions(preds, top=top)
#     622
#     623
#
# /usr/local/lib/python3.9/dist-packages/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     151
#     152     if len(preds.shape) != 2 or preds.shape[1] != 1000:
# --> 153         raise ValueError(
#     154             "`decode_predictions` expects "
#     155             "a batch of predictions "
#
# ...

# %%
pip install youtube-search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from youtube_search import YoutubeSearch
import webbrowser
mysong = input('Nhap: ')
result = YoutubeSearch(mysong, max_results=10).to_dict()
print(result)
print(result[0]['url_suffix'])
url = ('http://www.youtube.com'+result[0]['url_suffix'])
print(url)
webbrowser.open(url)
print('Video yêu thích của bạn đã được mở')
# Out:
# Nhap: man united
# ...

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from youtube_search import YoutubeSearch
